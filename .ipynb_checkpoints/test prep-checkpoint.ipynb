# %%
import pandas as pd
import numpy as np

# %%
food = pd.read_csv('openfoodfacts.csv', engine = 'python', sep = '\t', on_bad_lines = 'skip')

# %%
food.shape
# Out:
# (320767, 162)

# %%
food_head = food.head(200)

# %%
food_head.describe()
# Out:
#        no_nutriments  additives_n  ingredients_from_palm_oil_n  \
# count            0.0   188.000000                        188.0
# mean             NaN     0.547872                          0.0
# std              NaN     1.411506                          0.0
# min              NaN     0.000000                          0.0
# 25%              NaN     0.000000                          0.0
# 50%              NaN     0.000000                          0.0
# 75%              NaN     0.000000                          0.0
# max              NaN    10.000000                          0.0
#
#        ingredients_from_palm_oil  ingredients_that_may_be_from_palm_oil_n  \
# count                        0.0                               188.000000
# mean                         NaN                                 0.026596
# std                          NaN                                 0.241065
# min                          NaN                                 0.000000
# ...

# %%
food.dtypes
# Out:
# code                        object
# url                         object
# creator                     object
# created_t                   object
# created_datetime            object
#                             ...
# carbon-footprint_100g      float64
# nutrition-score-fr_100g    float64
# nutrition-score-uk_100g    float64
# glycemic-index_100g        float64
# water-hardness_100g        float64
# Length: 162, dtype: object

# %%
food_head.to_csv('food_head.csv')

# %%
food.describe()
# Out:
#        no_nutriments    additives_n  ingredients_from_palm_oil_n  \
# count            0.0  248934.000000                248934.000000
# mean             NaN       1.936047                     0.019660
# std              NaN       2.502036                     0.140526
# min              NaN       0.000000                     0.000000
# 25%              NaN       0.000000                     0.000000
# 50%              NaN       1.000000                     0.000000
# 75%              NaN       3.000000                     0.000000
# max              NaN      31.000000                     2.000000
#
#        ingredients_from_palm_oil  ingredients_that_may_be_from_palm_oil_n  \
# count                        0.0                            248934.000000
# mean                         NaN                                 0.055248
# std                          NaN                                 0.269210
# min                          NaN                                 0.000000
# ...

# %% [markdown]
# 1. Nettoyage :  Sélectionner les variables et individus valides  (4 méthodes)
#     - retenir les variables avec plus 10000 individus avec valeurs .
#     - éliminer les individus dont plus 50% valeurs sont manquantes pour les variables
#     - éliminer les variables doublons
#     - éliminer les individus doublons
#     - formaliser les variables

# %%
print(food.isnull().sum())
# Out:
# code                           23
# url                            23
# creator                         2
# created_t                       3
# created_datetime                9
#                             ...
# carbon-footprint_100g      320499
# nutrition-score-fr_100g     99561
# nutrition-score-uk_100g     99561
# glycemic-index_100g        320767
# water-hardness_100g        320767
# Length: 162, dtype: int64

# %%
food_var = food.dropna(axis = 1, thresh = 10000)

# %%
food_var.describe()
# Out:
#          additives_n  ingredients_from_palm_oil_n  \
# count  248934.000000                248934.000000
# mean        1.936047                     0.019660
# std         2.502036                     0.140526
# min         0.000000                     0.000000
# 25%         0.000000                     0.000000
# 50%         1.000000                     0.000000
# 75%         3.000000                     0.000000
# max        31.000000                     2.000000
#
#        ingredients_that_may_be_from_palm_oil_n   energy_100g       fat_100g  \
# count                            248934.000000  2.611080e+05  243886.000000
# mean                                  0.055248  1.141908e+03      12.730394
# std                                   0.269210  6.447215e+03      17.578871
# min                                   0.000000  0.000000e+00       0.000000
# 25%                                   0.000000  3.770000e+02       0.000000
# ...

# %%
food_var.head(1000).to_csv('food_var_head.csv')

# %% [markdown]
# 1. Nettoyage :  Sélectionner les variables et individus valides  (4 méthodes)
#     - éliminer les variables doublons qui termine par '_tags' ou '_fr'

# %%
food_var.shape
# Out:
# (320767, 79)

# %%
food_var1 = food_var.drop(['created_t'], axis = 1)

# %%
food_var1 =food_var1.drop(['last_modified_t'], axis = 1)

# %%
test = 'packaging_tags'
test[-5:]
# Out:
# '_tags'

# %%
for var in food_var1:
    if (var[-5:] == '_tags') :
        food_var1 = food_var1.drop([var], axis =1)

# %%
food_var1.shape
# Out:
# (320767, 64)

# %%
for var in food_var1:
    if (var[-3:] == 'url') :
        food_var1 = food_var1.drop([var], axis =1)

# %%
food_var1.shape
# Out:
# (320767, 61)

# %%
for var in food_var1:
    if (var[-3:] == '_fr' and var[-8:] != 'grade_fr') :
        food_var1 = food_var1.drop([var], axis =1)

# %%
food_var1.shape
# Out:
# (320767, 54)

# %% [markdown]
# 1. Nettoyage :  Sélectionner les variables et individus valides  (4 méthodes)
#     - retenir les variables avec plus 10000 individus avec valeurs .
#     - éliminer les variables non signficatives :

# %%
food_var2 = food_var1.drop(['created_datetime', 'generic_name','packaging','manufacturing_places',
                           'origins','labels','emb_codes','purchase_places','first_packaging_code_geo',
                           'stores','traces','ingredients_from_palm_oil_n','ingredients_that_may_be_from_palm_oil_n',
                           'additives_n','additives','states'], axis =1)

# %%
food_var2.shape
# Out:
# (320767, 38)

# %%
food_var2.head(500).to_csv("food_var2.csv")
