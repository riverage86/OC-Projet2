# %%
import pandas as pd
import numpy as np

# %%
food = pd.read_csv('openfoodfacts.csv', engine = 'python', sep = '\t', on_bad_lines = 'skip')

# %%
food.shape
# Out:
# (320767, 162)

# %%
food.describe()
# Out:
#        no_nutriments    additives_n  ingredients_from_palm_oil_n  \
# count            0.0  248934.000000                248934.000000
# mean             NaN       1.936047                     0.019660
# std              NaN       2.502036                     0.140526
# min              NaN       0.000000                     0.000000
# 25%              NaN       0.000000                     0.000000
# 50%              NaN       1.000000                     0.000000
# 75%              NaN       3.000000                     0.000000
# max              NaN      31.000000                     2.000000
#
#        ingredients_from_palm_oil  ingredients_that_may_be_from_palm_oil_n  \
# count                        0.0                            248934.000000
# mean                         NaN                                 0.055248
# std                          NaN                                 0.269210
# min                          NaN                                 0.000000
# ...

# %% [markdown]
# 1. Nettoyage :  Sélectionner les variables et individus valides
# - retenir les variables avec plus 10% individus avec valeurs .

# %%
food.notna().sum()/len(food)
# Out:
# code                       0.999928
# url                        0.999928
# creator                    0.999994
# created_t                  0.999991
# created_datetime           0.999972
#                              ...
# carbon-footprint_100g      0.000835
# nutrition-score-fr_100g    0.689616
# nutrition-score-uk_100g    0.689616
# glycemic-index_100g        0.000000
# water-hardness_100g        0.000000
# Length: 162, dtype: float64

# %%
food_var = food
for var in food:
    if food[var].isna().sum()/len(food) > 0.9:
        food_var = food_var.drop([var], axis = 1)

# %%
food_var.shape
# Out:
# (320767, 62)

# %% [markdown]
# 1. Nettoyage :  Sélectionner les variables et individus valides  (4 méthodes)
#     - éliminer les variables doublons qui termine par '_tags', 'url',  '_fr'

# %%
food_var1 = food_var.drop(['created_t', 'last_modified_t'], axis = 1)

# %%
for var in food_var1:
    if (var[-3:] == 'url' or var[-5:] == '_tags') :
        food_var1 = food_var1.drop([var], axis =1)

# %%
for var in food_var1:
    if (var[-3:] == '_fr' and var[-8:] != 'grade_fr') :
        food_var1 = food_var1.drop([var], axis =1)

# %% [markdown]
# 1. Nettoyage :  Sélectionner les variables et individus valides  (4 méthodes)
#     - éliminer les variables non signficatives :

# %%
food_var2 = food_var1.drop(['creator','created_datetime', 'generic_name','packaging','manufacturing_places',
                           'labels','ingredients_text','purchase_places','main_category',
                           'stores','ingredients_from_palm_oil_n','ingredients_that_may_be_from_palm_oil_n',
                           'additives_n','additives','states', 'pnns_groups_1','pnns_groups_2',
                           'nutrition-score-uk_100g'], axis =1)

# %%
food_var2.shape
# Out:
# (320767, 25)

# %% [markdown]
# Nettoyage:   éliminier les individus avec code ou product_name vide

# %%
food_var_obj = food_var2.loc[food_var2['product_name'].notna()]

# %%
food_var_obj = food_var_obj.loc[food_var_obj['code'].notna()]

# %%
food_var_obj.shape
# Out:
# (302982, 25)

# %% [markdown]
# Nettoyage:  Remove duplicated row where 'code' is the same

# %%
food_var_obj = food_var_obj.drop_duplicates(subset = ['code'], keep = 'first')

# %% [markdown]
# Nettoyage:  elimine les individus dont des valeurs nutritionnelles sont manquantes

# %%
food_var_obj1 = food_var_obj

# %%
for var in food_var_obj1 :
    if var[-5:] == '_100g':
        food_var_obj1 = food_var_obj1.loc[food_var_obj1[var].notna()]

# %%
food_var_obj1.shape
# Out:
# (126286, 25)

# %% [markdown]
# Vérification de complétude des données

# %%
food_var_obj1.notna().sum()/len(food_var_obj1)
# Out:
# code                       1.000000
# last_modified_datetime     1.000000
# product_name               1.000000
# quantity                   0.008956
# brands                     0.994410
# categories                 0.008029
# countries                  1.000000
# serving_size               0.999968
# nutrition_grade_fr         1.000000
# energy_100g                1.000000
# fat_100g                   1.000000
# saturated-fat_100g         1.000000
# trans-fat_100g             1.000000
# cholesterol_100g           1.000000
# carbohydrates_100g         1.000000
# sugars_100g                1.000000
# fiber_100g                 1.000000
# proteins_100g              1.000000
# salt_100g                  1.000000
# sodium_100g                1.000000
# vitamin-a_100g             1.000000
# vitamin-c_100g             1.000000
# calcium_100g               1.000000
# iron_100g                  1.000000
# nutrition-score-fr_100g    1.000000
# dtype: float64

# %% [markdown]
# Nettoyage:  enlève les variables quantity et catégories qui ont trop peu de valeurs, et les individus avec les brand ou serving manquants

# %%
food_var_obj2 = food_var_obj1 
food_var_obj2 = food_var_obj2.drop(['quantity', 'categories'], axis = 1)

# %%
food_var_obj2.shape
# Out:
# (126286, 23)

# %%
food_var_obj2 = food_var_obj2.loc[food_var_obj2['brands'].notna()]

# %%
food_var_obj2 = food_var_obj2.loc[food_var_obj2['serving_size'].notna()]

# %%
food_var_obj2.notna().sum()/len(food_var_obj2)
# Out:
# code                       1.0
# last_modified_datetime     1.0
# product_name               1.0
# brands                     1.0
# countries                  1.0
# serving_size               1.0
# nutrition_grade_fr         1.0
# energy_100g                1.0
# fat_100g                   1.0
# saturated-fat_100g         1.0
# trans-fat_100g             1.0
# cholesterol_100g           1.0
# carbohydrates_100g         1.0
# sugars_100g                1.0
# fiber_100g                 1.0
# proteins_100g              1.0
# salt_100g                  1.0
# sodium_100g                1.0
# vitamin-a_100g             1.0
# vitamin-c_100g             1.0
# calcium_100g               1.0
# iron_100g                  1.0
# nutrition-score-fr_100g    1.0
# dtype: float64

# %%
food_var_obj2.shape
# Out:
# (125576, 23)

# %% [markdown]
# nettoyage:   convertir valeur serving_size en numérique : uniformiser la valeur en gramme, écarter le valeurs non conformes.

# %%
food_var_obj3 = food_var_obj2.copy()

# %%
i = 0
j = len(food_var_obj3) - 1
while i < j: 
# convertir le content en mots séparés,  prendre le premier mot comme valeur en gramme.
    mylist = food_var_obj3['serving_size'].iloc[i].split(" ")
    if len(mylist) > 1:
        if mylist[1] == 'g' or mylist[1] == 'ml' or mylist[1] == 'G' : 
            food_var_obj3['serving_size'].iloc[i] = mylist[0]
            i+=1
        else: 
            food_var_obj3 = food_var_obj3.drop(index=food_var_obj3.iloc[i].name)
            j-=1
    else: 
        food_var_obj3 = food_var_obj3.drop(index=food_var_obj3.iloc[i].name)
        j-=1
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_21920\1648397617.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   food_var_obj3['serving_size'].iloc[i] = mylist[0]
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_21920\1648397617.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   food_var_obj3['serving_size'].iloc[i] = mylist[0]
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_21920\1648397617.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
food_var_obj3.shape
# Out:
# (124987, 23)

# %%
food_var_obj3.describe()
# Out:
#          energy_100g       fat_100g  saturated-fat_100g  trans-fat_100g  \
# count  124987.000000  124987.000000       124987.000000   124987.000000
# mean     1214.384966      13.411680            4.720510        0.068813
# std       746.996762      15.493346            6.846534        1.567122
# min         0.000000       0.000000            0.000000       -3.570000
# 25%       494.000000       0.830000            0.000000        0.000000
# 50%      1272.000000       7.810000            1.790000        0.000000
# 75%      1761.000000      21.430000            7.140000        0.000000
# max     14644.000000     100.000000          100.000000      369.000000
#
#        cholesterol_100g  carbohydrates_100g    sugars_100g     fiber_100g  \
# count     124987.000000       124987.000000  124987.000000  124987.000000
# mean           0.018436           35.533402      15.396121       2.858869
# std            0.323980           28.161426      19.526874       4.404042
# ...

# %% [markdown]
# Nettoyage:  Eliminer les individus dont des valeurs de nutrition sont invalides (< 0, ou > 100)

# %%
for var in food_var_obj3 :
    if var[-5:] == '_100g' and var[0:6] != 'energy':
        food_var_obj3 = food_var_obj3.loc[food_var_obj3[var] >=0]

# %%
food_var_obj3.shape
# Out:
# (104839, 23)

# %%
for var in food_var_obj3 :
    if var[-5:] == '_100g' and var[0:6] != 'energy':
        food_var_obj3 = food_var_obj3.loc[food_var_obj3[var] <=100]

# %%
food_var_obj3.shape
# Out:
# (104803, 23)

# %%
food_var_obj3.describe()
# Out:
#          energy_100g       fat_100g  saturated-fat_100g  trans-fat_100g  \
# count  104803.000000  104803.000000       104803.000000   104803.000000
# mean     1312.715005      15.501324            5.572909        0.068847
# std       739.101057      15.964188            7.162016        0.841900
# min         0.000000       0.000000            0.000000        0.000000
# 25%       699.000000       1.750000            0.000000        0.000000
# 50%      1393.000000      11.360000            3.330000        0.000000
# 75%      1858.000000      25.000000            8.330000        0.000000
# max     14644.000000     100.000000          100.000000      100.000000
#
#        cholesterol_100g  carbohydrates_100g    sugars_100g     fiber_100g  \
# count     104803.000000       104803.000000  104803.000000  104803.000000
# mean           0.019747           36.784515      17.711352       2.518666
# std            0.296230           28.117094      20.457734       3.849128
# ...

# %%
food_var_obj3.to_csv('food_data.csv')

# %% [markdown]
# Nettoyage:  convertir serving_size en float

# %%
# food_sample['serving_size'] = food_sample['serving_size'].astype('float64')
